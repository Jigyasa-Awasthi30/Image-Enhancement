# %% [markdown]
# <a href="https://colab.research.google.com/github/Jigyasa-Awasthi30/Image-Enhancement/blob/main/Image_Enhancement7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MOUNTING THE GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ##  INDEPENDENT COMPONENT ANALYSIS

# %% [markdown]
# **Independent Component Analysis or short for ICA is a technique for separating a multivariate signal into its underlying component. ICA helps in the extraction of the desired component from the mixture of multiple components or signals.**

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
from sklearn.decomposition import FastICA
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/download.png")
print("ORGINAL IMAGE")
cv2_imshow(image)
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
print("GRAY IMAGE")
cv2_imshow(gray)
print("RESHAPED IMAGE")
gray=gray.reshape((gray.shape[0]*gray.shape[1],1))
print(gray.shape)
ica=FastICA(n_components=1)
components=ica.fit_transform(gray)
print(components.shape)
print("COMPONENTS")
print(components)
# Out:
# ORGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=334x151>
# GRAY IMAGE
# <PIL.Image.Image image mode=L size=334x151>
# RESHAPED IMAGE
# (50434, 1)
# (50434, 1)
# COMPONENTS
# [[-0.4358403]
#  [-0.4358403]
#  [-0.4358403]
#  ...
#  [-0.4358403]
#  [-0.4358403]
#  [-0.4358403]]

# %% [markdown]
# # EDGE DETECTION

# %% [markdown]
# **Edge detection involves identifying the boundaries within an image. Techniques like the Sobel, Canny, and Prewitt operators are used to detect edges by finding areas of high intensity gradient.**

# %% [markdown]
# *SOBEL EDGE DETECTION*

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/natureimage.jpg")
print("ORGINAL IMAGE")
cv2_imshow(image)
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
print("GRAY IMAGE")
cv2_imshow(gray)
sobelx=cv2.Sobel(gray,cv2.CV_64F,1,0)
sobely=cv2.Sobel(gray,cv2.CV_64F,0,1)
sobelxy=cv2.Sobel(gray,cv2.CV_64F,1,1)
print("SOBELX IMAGE")
cv2_imshow(sobelx)
print("SOBELY IMAGE")
cv2_imshow(sobely)
print("SOBELXY IMAGE")
cv2_imshow(sobelxy)
# Out:
# ORGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=357x200>
# GRAY IMAGE
# <PIL.Image.Image image mode=L size=357x200>
# SOBELX IMAGE
# <PIL.Image.Image image mode=L size=357x200>
# SOBELY IMAGE
# <PIL.Image.Image image mode=L size=357x200>
# SOBELXY IMAGE
# <PIL.Image.Image image mode=L size=357x200>

# %% [markdown]
# *CANNY EDGE DETECTION*

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/images.jpeg")
print("ORGINAL IMAGE")
cv2_imshow(image)
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
print("GRAY IMAGE")
blurred=cv2.GaussianBlur(gray_image,(5,5),0)
print("BLURRED IMAGE")
cv2_imshow(blurred)
canny=cv2.Canny(blurred,30,150)
print("CANNY IMAGE")
cv2_imshow(canny)
# Out:
# ORGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=159x316>
# GRAY IMAGE
# BLURRED IMAGE
# <PIL.Image.Image image mode=L size=159x316>
# CANNY IMAGE
# <PIL.Image.Image image mode=L size=159x316>

# %% [markdown]
# *LAPLACIAN EDGE DETECTION*

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/images.jpeg")
print("ORGINAL IMAGE")
cv2_imshow(image)
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
print("GRAY IMAGE")
blurred=cv2.GaussianBlur(gray_image,(5,5),0)
print("BLURRED IMAGE")
cv2_imshow(blurred)
laplacian=cv2.Laplacian(blurred,cv2.CV_64F)
print("LAPLACIAN IMAGE")
cv2_imshow(laplacian)
# Out:
# ORGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=159x316>
# GRAY IMAGE
# BLURRED IMAGE
# <PIL.Image.Image image mode=L size=159x316>
# LAPLACIAN IMAGE
# <PIL.Image.Image image mode=L size=159x316>
