# %% [markdown]
# <a href="https://colab.research.google.com/github/Jigyasa-Awasthi30/Image-Enhancement/blob/main/Image_Enhancement11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MOUNTING THE GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # SHAPE AND TEXTURE ANALYSIS

# %% [markdown]
# **Shape and texture analysis techniques are used to identify and quantify the shapes and textures within an image. Methods like edge detection, contour analysis, and texture filters help in understanding the geometric and surface properties of objects in the image.**

# %% [markdown]
# SHAPE ANALYSIS

# %% [markdown]
# **Shape analysis involves identifying and extracting geometric features from an object or region in an image. Key methods used in shape analysis include contour detection, region properties, and shape descriptors.**

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/2_70cb0e7d-22aa-4df7-8456-0fdf7b709476.webp")
print("ORGINAL IMAGE")
cv2_imshow(image)
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
print("GRAY IMAGE")
cv2_imshow(gray_image)
blurred=cv2.GaussianBlur(gray_image,(5,5),0)
print("BLURRED IMAGE")
cv2_imshow(blurred)
ret,thresh=cv2.threshold(blurred,127,255,cv2.THRESH_BINARY)
print("THRESHOLD IMAGE")
cv2_imshow(thresh)
contours,hierarchy=cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
print("CONTOURS")
print(contours)
cv2.drawContours(image,contours,-1,(0,255,0),3)
print("IMAGE WITH CONTOURS")
cv2_imshow(image)

# %% [markdown]
# *Texture Analysis*

# %% [markdown]
# **Texture analysis focuses on extracting features related to the patterns of pixel intensities, such as smoothness, roughness, or repeating patterns. It is often used in applications like material classification, image segmentation, and surface inspection.**

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/2_70cb0e7d-22aa-4df7-8456-0fdf7b709476.webp")
print("ORGINAL IMAGE")
cv2_imshow(image)
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
print("GRAY IMAGE")
cv2_imshow(gray_image)
blurred=cv2.GaussianBlur(gray_image,(5,5),0)
print("BLURRED IMAGE")
cv2_imshow(blurred)
sobelx=cv2.Sobel(blurred,cv2.CV_64F,1,0,ksize=5)
sobely=cv2.Sobel(blurred,cv2.CV_64F,0,1,ksize=5)
sobelxy=cv2.Sobel(blurred,cv2.CV_64F,1,1,ksize=5)
print("SOBELX IMAGE")
cv2_imshow(sobelx)
print("SOBELY IMAGE")
cv2_imshow(sobely)
print("SOBELXY IMAGE")
cv2_imshow(sobelxy)
# Out:
# ORGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=699x699>
# GRAY IMAGE
# <PIL.Image.Image image mode=L size=699x699>
# BLURRED IMAGE
# <PIL.Image.Image image mode=L size=699x699>
# SOBELX IMAGE
# <PIL.Image.Image image mode=L size=699x699>
# SOBELY IMAGE
# <PIL.Image.Image image mode=L size=699x699>
# SOBELXY IMAGE
# <PIL.Image.Image image mode=L size=699x699>

# %% [markdown]
# # Morphological Processing

# %% [markdown]
# **Morphological processing refers to a set of image processing techniques that focus on the shape or structure of objects within an image. **

# %% [markdown]
# *Dilation and Erosion*

# %% [markdown]
# **Dilation and erosion are basic morphological operations used to process binary images. Dilation adds pixels to the boundaries of objects, making them larger, while erosion removes pixels from the boundaries, making objects smaller.**

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/2_70cb0e7d-22aa-4df7-8456-0fdf7b709476.webp")
print("ORGINAL IMAGE")
cv2_imshow(image)
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
print("GRAY IMAGE")
cv2_imshow(gray_image)
kernel=np.ones((5,5),np.uint8)
dilation=cv2.dilate(gray_image,kernel,iterations=1)
print("DILATED IMAGE")
cv2_imshow(dilation)
erosion=cv2.erode(gray_image,kernel,iterations=1)
print("EROSION IMAGE")
cv2_imshow(erosion)
# Out:
# ORGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=699x699>
# GRAY IMAGE
# <PIL.Image.Image image mode=L size=699x699>
# DILATED IMAGE
# <PIL.Image.Image image mode=L size=699x699>
# EROSION IMAGE
# <PIL.Image.Image image mode=L size=699x699>
