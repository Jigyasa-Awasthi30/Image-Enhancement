# %% [markdown]
# <a href="https://colab.research.google.com/github/Jigyasa-Awasthi30/Image-Enhancement/blob/main/Image_Enhancement1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MOUNTING THE GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # IMAGE TO ARRAY FORMAT

# %%
import cv2
print("ORIGINAL IMAGE")
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/god.jpeg")
from google.colab.patches import cv2_imshow
cv2_imshow(image)
print("Array format")
from numpy import asarray
data=asarray(image)
print(data)
# Out:
# ORIGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=270x180>
# Array format
# [[[141 102 100]
#   [114  76  72]
#   [ 85  44  41]
#   ...
#   [ 59  29   0]
#   [ 61  31   2]
#   [ 63  33   4]]
#
#  [[105  64  61]
#   [ 96  56  51]
#   [ 89  47  40]
#   ...
#   [ 60  30   1]
#   [ 62  32   3]
#   [ 63  33   4]]
#
#  [[ 78  37  28]
#   [ 85  44  35]
#   [ 96  54  42]
#   ...
#   [ 60  30   1]
#   [ 62  32   3]
#   [ 63  33   4]]
#
#  ...
#
#  [[ 33   8   6]
#   [ 24   0   0]
#   [ 27   4   2]
#   ...
#   [ 80  54  18]
#   [ 90  62  28]
#   [ 88  60  26]]
#
#  [[ 45  20  18]
#   [ 28   3   1]
#   [ 24   1   0]
#   ...
#   [ 80  54  18]
#   [ 89  61  27]
#   [ 92  64  30]]
#
#  [[ 57  32  30]
#   [ 31   6   4]
#   [ 22   0   0]
#   ...
#   [ 78  52  16]
#   [ 86  58  24]
#   [ 92  64  30]]]

# %% [markdown]
# # CONVERTING RBG COMPONENT TO CMY COMPONENT

# %%
import cv2
from google.colab.patches import cv2_imshow
print("ORIGINAL IMAGE")
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/god.jpeg")
cv2_imshow(image)
r,g,b=cv2.split(image)
print("R Component")
cv2_imshow(r)
print("G Component")
cv2_imshow(g)
print("B Component")
cv2_imshow(b)
print("C Component")
c=1-r
cv2_imshow(c)
print("M Component")
m=1-g
cv2_imshow(m)
print("Y Component")
y=1-b
cv2_imshow(y)
# Out:
# ORIGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=270x180>
# R Component
# <PIL.Image.Image image mode=L size=270x180>
# G Component
# <PIL.Image.Image image mode=L size=270x180>
# B Component
# <PIL.Image.Image image mode=L size=270x180>
# C Component
# <PIL.Image.Image image mode=L size=270x180>
# M Component
# <PIL.Image.Image image mode=L size=270x180>
# Y Component
# <PIL.Image.Image image mode=L size=270x180>

# %% [markdown]
# # IMUTILS LIBRARY

# %%
import cv2
import imutils
print("ORIGINAL IMAGE")
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/god.jpeg")
from google.colab.patches import cv2_imshow
cv2_imshow(image)
print("ROTATED IMAGE")
r1=imutils.rotate(image,45)
cv2_imshow(r1)
print("TRANSLATIONAL IMAGE")
R2=imutils.translate(image,25,75)
cv2_imshow(R2)
print("RESIZED IMAGE")
r3=imutils.resize(image,width=125)
cv2_imshow(r3)
print("RESIZE IMAGE WITHOUT ASPECT RATIO")
r4=cv2.resize(image,(125,125))
cv2_imshow(r4)
# Out:
# ORIGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=270x180>
# ROTATED IMAGE
# <PIL.Image.Image image mode=RGB size=270x180>
# TRANSLATIONAL IMAGE
# <PIL.Image.Image image mode=RGB size=270x180>
# RESIZED IMAGE
# <PIL.Image.Image image mode=RGB size=125x83>
# RESIZE IMAGE WITHOUT ASPECT RATIO
# <PIL.Image.Image image mode=RGB size=125x125>
